# %% [markdown]
# <제목>
# # 제목1

# %%
import sys
print(sys.executable)

import torch
print(torch.__version__, torch.cuda.is_available())

import hat.archs.DRCT_arch as DRCT
print("hat import OK")
# Out:
# /home/vclab2080ti/anaconda3/envs/drct-jupyter/bin/python
# 1.12.1 True
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-fe19f5dd7ad4> in <cell line: 7>()
#       5 print(torch.__version__, torch.cuda.is_available())
#       6
# ----> 7 import hat.archs.DRCT_arch as DRCT
#       8 print("hat import OK")
#
# ModuleNotFoundError: No module named 'hat'
